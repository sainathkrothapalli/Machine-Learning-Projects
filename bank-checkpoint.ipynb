# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Desktop/bank.txt')
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon ...       1.0  999.0       0.0  nonexistent          1.1
# 1   may         mon ...       1.0  999.0       0.0  nonexistent          1.1
# 2   may         mon ...       1.0  999.0       0.0  nonexistent          1.1
# 3   may         mon ...       1.0  999.0       0.0  nonexistent          1.1
# 4   may         mon ...       1.0  999.0       0.0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# ...

# %%
df.shape
# Out:
# (24204, 21)

# %%
df.drop(df.tail(1).index,inplace=True)

# %%
df.shape
# Out:
# (24203, 21)

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 21

# %%
cat_features=[i for i in df.columns if df.dtypes[i]=='object']
cat_features
# Out:
# ['job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'day_of_week',
#  'poutcome',
#  'y']

# %%
df['y']=df['y'].map({'yes': 1, 'no': 0})

# %%
df['y'].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: y, dtype: int64

# %%
num_features=[i for i in df.columns if (df.dtypes[i]=='int64' or df.dtypes[i]=='float64') and i!='y']
num_features
# Out:
# ['age',
#  'duration',
#  'campaign',
#  'pdays',
#  'previous',
#  'emp.var.rate',
#  'cons.price.idx',
#  'cons.conf.idx',
#  'euribor3m',
#  'nr.employed']

# %%
len(cat_features)+len(num_features)
# Out:
# 21

# %%
null_values=[]
col=['Count of Null values']
for i in num_features:
    null_values.append(df[i].isnull().sum())
nullValues=pd.DataFrame(data=null_values,index=num_features,columns=col)    
nullValues
# Out:
#                 Count of Null values
# age                                0
# duration                           0
# campaign                           0
# pdays                              0
# previous                           0
# emp.var.rate                       0
# cons.price.idx                     0
# cons.conf.idx                      0
# euribor3m                          0
# nr.employed                        0

# %%
def Numerical_desc(feature):
    print(df[feature].describe())
    sns.distplot(df[feature],kde=True)
    print('Skewness',":",df[feature].skew())
    print('Kurtosis',":",df[feature].kurtosis())

# %%
Numerical_desc('age')
# Out:
# count    24203.000000
# mean        40.130232
# std          9.287130
# min         18.000000
# 25%         33.000000
# 50%         39.000000
# 75%         47.000000
# max         61.000000
# Name: age, dtype: float64
# Skewness : 0.3061486071719057
# Kurtosis : -0.8752262615246522

# %%
sns.boxplot(x='y',y='age',data=df)

# %%
Numerical_desc('campaign')
# Out:
# count    24203.000000
# mean         2.922406
# std          3.310816
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         56.000000
# Name: campaign, dtype: float64
# Skewness : 4.287965459027504
# Kurtosis : 27.962910898365116

# %%
sns.boxplot(x='y',y='campaign',data=df)

# %%
Numerical_desc('pdays')
# Out:
# count    24203.000000
# mean       998.958972
# std          6.382850
# min          6.000000
# 25%        999.000000
# 50%        999.000000
# 75%        999.000000
# max        999.000000
# Name: pdays, dtype: float64
# Skewness : -155.57313392742338
# Kurtosis : 24203.00000000001

# %%
Numerical_desc('previous')
# Out:
# count    24203.000000
# mean         0.000868
# std          0.029444
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: previous, dtype: float64
# Skewness : 33.906742383110895
# Kurtosis : 1147.7620236361367

# %%
sns.boxplot(x='y',y='previous',data=df)

# %%
Numerical_desc('emp.var.rate')
# Out:
# count    24203.000000
# mean         1.291009
# std          0.190106
# min         -0.100000
# 25%          1.100000
# 50%          1.400000
# 75%          1.400000
# max          1.400000
# Name: emp.var.rate, dtype: float64
# Skewness : -3.533672807597455
# Kurtosis : 21.80327844720487

# %%
sns.boxplot(x='y',y='emp.var.rate',data=df)

# %%
Numerical_desc('cons.price.idx')
# Out:
# count    24203.000000
# mean        93.935427
# std          0.326599
# min         93.200000
# 25%         93.918000
# 50%         93.994000
# 75%         93.994000
# max         94.465000
# Name: cons.price.idx, dtype: float64
# Skewness : -0.021928201796666144
# Kurtosis : -0.506291414624847

# %%
Numerical_desc('cons.conf.idx')
# Out:
# count    24203.000000
# mean       -39.095079
# std          3.035292
# min        -42.700000
# 25%        -42.700000
# 50%        -36.400000
# 75%        -36.400000
# max        -36.100000
# Name: cons.conf.idx, dtype: float64
# Skewness : -0.16593510167639575
# Kurtosis : -1.929540837872783

# %%
'euribor3m',
 'nr.employed'

# %%
Numerical_desc('euribor3m')
# Out:
# count    24203.000000
# mean         4.919636
# std          0.070182
# min          4.191000
# 25%          4.859000
# 50%          4.960000
# 75%          4.963000
# max          5.045000
# Name: euribor3m, dtype: float64
# Skewness : -4.862622376651508
# Kurtosis : 45.06569790870634

# %%
Numerical_desc('nr.employed')
# Out:
# count    24203.000000
# mean      5215.925431
# std         17.382441
# min       5191.000000
# 25%       5191.000000
# 50%       5228.100000
# 75%       5228.100000
# max       5228.100000
# Name: nr.employed, dtype: float64
# Skewness : -0.7285518058588399
# Kurtosis : -1.46713669584774

# %%
sns.boxplot(x='y',y='duration',data=df)

# %%
sns.FacetGrid(df, hue='y', size=5) \
.map(sns.distplot, 'duration') \
.add_legend()
# Out:
# D:\Users\admin\Anaconda3\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
cat_features
# Out:
# ['job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'day_of_week',
#  'poutcome',
#  'y']

# %%
sns.countplot(x='job',hue='y',data=df)

# %%
sns.countplot(x='contact',hue='y',data=df)

# %%
sns.countplot(x='education',hue='y',data=df)

# %%
sns.countplot(x='housing',hue='y',data=df)

# %%
sns.countplot(x='poutcome',hue='y',data=df)

# %%
sns.pairplot(df,hue='y')

# %%
corr=df[num_features+['y']].corr()
sns.heatmap(corr,annot=True)

# %%
Y=df['y']

# %%
df['job'] = df['job'].astype('category').cat.codes
df['marital'] = df['marital'].astype('category').cat.codes
df['education'] = df['education'].astype('category').cat.codes
df['contact'] = df['contact'].astype('category').cat.codes
df['poutcome'] = df['poutcome'].astype('category').cat.codes
df['month'] = df['month'].astype('category').cat.codes
df['default'] = df['default'].astype('category').cat.codes
df['loan'] = df['loan'].astype('category').cat.codes
df['housing'] = df['housing'].astype('category').cat.codes

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(df.drop(['day_of_week','y'], axis=1),Y,test_size=0.2,random_state=0)

# %%
from sklearn.tree import DecisionTreeClassifier
lc=DecisionTreeClassifier()
lc.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
lc.feature_importances_
# Out:
# array([0.10463518, 0.05451306, 0.02603925, 0.04632467, 0.01535698,
#        0.02401054, 0.01512126, 0.00895706, 0.02591081, 0.49891168,
#        0.05702444, 0.        , 0.00065872, 0.0008563 , 0.00125214,
#        0.01013896, 0.0087962 , 0.10075108, 0.00074167])

# %%
importances = lc.feature_importances_
feature_names = df.drop(['y','day_of_week'], axis=1).columns
indices = np.argsort(importances)

def feature_importance_graph(indices, importances, feature_names):
    plt.figure(figsize=(12,6))
    plt.title("Feature Importance", fontsize=10)
    plt.barh(range(len(indices)), importances[indices], color='r',  align="center")
    plt.yticks(range(len(indices)), feature_names[indices], rotation='horizontal',fontsize=14)
    plt.ylim([-1, len(indices)])
    
feature_importance_graph(indices, importances, feature_names)
plt.show()

# %%
X1=df[['duration','age','euribor3m','campaign','job','education','marital','month','housing','loan']]

# %%
x_train,x_test,y_train,y_test=train_test_split(X1,Y,test_size=0.2,random_state=0)

# %%
x_train.shape
# Out:
# (19362, 10)

# %%
from sklearn.ensemble import RandomForestClassifier
rc=RandomForestClassifier()
rc.fit(x_train,y_train)
# Out:
# D:\Users\admin\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
pred=rc.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
a1=accuracy_score(y_test,pred)
a1
# Out:
# 0.9557942573848378

# %%
confusion_matrix(y_test,pred)
# Out:
# array([[4559,   57],
#        [ 157,   68]], dtype=int64)

# %%
from xgboost import XGBClassifier
xg=XGBClassifier()
xg.fit(x_train,y_train)
pred1=xg.predict(x_test)
a2=accuracy_score(y_test,pred1)
a2
# Out:
# 0.9603387729807891

# %%
confusion_matrix(y_test,pred1)
# Out:
# array([[4559,   57],
#        [ 135,   90]], dtype=int64)

# %%
score=[a1,a2]
col=['score']
model=['random forest','xgboost']
data=pd.DataFrame(data=score,index=model,columns=col)
data
# Out:
#                   score
# random forest  0.955794
# xgboost        0.960339
